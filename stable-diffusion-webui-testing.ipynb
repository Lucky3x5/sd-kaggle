# %%
# %env USE_PERSISTENCE=0
# %env INSTALL_CONTROLNET=0
# %env FORCE_REINSTALL=0
# %env SD_MODELS=https://huggingface.co/nolanaatama/urpm13/resolve/main/urpm13.ckpt

# !mkdir -p /kaggle/tmp
# %cd /kaggle/tmp
# !git clone https://github.com/Lucky3x5/sd-kaggle.git
# %cd /kaggle/tmp/sd-kaggle
# !git pull
# !git checkout testing
# %cd /kaggle/tmp
# !bash /kaggle/tmp/sd-kaggle/install-stable-diffusion-webui.sh
import os
if os.environ['USE_PERSISTENCE']:
    # !ln -sf /kaggle/working/stable-diffusion-webui /kaggle/tmp/stable-diffusion-webui
# %cd /kaggle/tmp/stable-diffusion-webui
# %env LD_PRELOAD=libtcmalloc.so
# %env VIRTUAL_ENV=/kaggle/tmp/stable-diffusion-webui/venv
os.environ['PATH']='/kaggle/tmp/stable-diffusion-webui/venv/bin:'+os.environ['PATH']
# !COMMANDLINE_ARGS="--skip-torch-cuda-test --share --xformers --enable-insecure-extension- --gradio-queue --no-hashing" REQS_FILE="requirements.txt" python launch.py
