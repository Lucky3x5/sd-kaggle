# %%
# %cd /kaggle/working
# !git clone https://github.com/Lucky3x5/sd-kaggle.git
# %env SD_MODELS=https://huggingface.co/nolanaatama/chomni/resolve/main/chomni.safetensors https://huggingface.co/nolanaatama/urpm13/resolve/main/urpm13.ckpt
# !bash /kaggle/working/sd-kaggle/install-stable-diffusion-webui.sh
# %cd /kaggle/working/stable-diffusion-webui
# %env LD_PRELOAD=libtcmalloc.so
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --xformers --reinstall-xformers --enable-insecure-extension- --gradio-queue --remotemoe" REQS_FILE="requirements.txt" python launch.py
